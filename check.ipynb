# %%
from models.counters.Res101_SFCN import Res101_SFCN
import torch

model = Res101_SFCN(True)
print(model)
# Out:
# Res101_SFCN(
#   (backend): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (11): ReLU(inplace=True)
#   )
#   (convDU): convDU(
#     (conv): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 9), stride=(1, 1), padding=(0, 4))
#       (1): ReLU(inplace=True)
#     )
#   )
# ...

# %%
x = torch.randn((1,3,768,1024))
out = model(x)
# Out:
# input shape:  torch.Size([1, 3, 768, 1024])
# frontend output shape:  torch.Size([1, 512, 96, 128])
# own_reslayer_3 output shape:  torch.Size([1, 1024, 96, 128])
# backend shape:  torch.Size([1, 64, 96, 128])
# convDU shape:  torch.Size([1, 64, 96, 128])
# convLR shape:  torch.Size([1, 64, 96, 128])
# output_layer shape:  torch.Size([1, 1, 96, 128])
# upsampling shape:  torch.Size([1, 1, 768, 1024])
# /home/camerayuhang/miniforge3/envs/torch_gpu/lib/python3.11/site-packages/torch/_tensor.py:836: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
